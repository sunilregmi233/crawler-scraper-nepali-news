# %%
from nltk.tokenize import word_tokenize
import nltk
import re

stopwords01 = open('/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/scraper/stopwords01.txt', 'r')
line = stopwords01.read()
words1 = line.split() 

stopwords = open('thahakhabar_text.txt', 'r')
line1 = stopwords.read()
words2 = line1.split()
# print(words2)

word_tokens = word_tokenize(str(line1))

filtered_sentence = [w for w in word_tokens if not w in words1]
  
# filtered_sentence = [] 
  
# for w in word_tokens: 
#     if w not in stopwords01: 
#         filtered_sentence.append(w) 

print(filtered_sentence)
# Out:
# ['काठमाडौं', ':', 'बागमती', 'प्रदेशको', 'ठूलो', 'भर्\u200dयाङस्थित', 'यातायात', 'व्यवस्था', 'कार्यालयका', 'जना', 'कर्मचारीमा', 'कोरोना', 'पुष्टि', 'भएपछि', 'अनिश्चितकालका', 'छ।', 'कार्यालयको', 'विज्ञप्तिमा', 'भनिएको', ',', "'यस", 'कार्यालयमा', 'कार्यरत', 'कर्मचारीमा', 'कोरोना', 'पोजेटिभ', 'भएपछि', '२७', 'गते', 'मंगलबारदेखि', 'सूचना', 'जारी', 'नभए', 'सम्मको', 'गरिएको', "छ।'एजेन्सी", ':', 'बंगलादेशले', 'बलात्कारीलाई', 'मृत्युदण्ड', 'दिने', 'विधेयक', 'पारित', 'छ।', 'बलात्कारीलाई', 'मृत्युदण्ड', 'दिनुपर्ने', 'आन्दोलन', 'चर्किएसँगै', 'सरकारले', 'मृत्युदण्ड', 'दिन', 'सकिने', 'कानुन', 'संशोधन', 'हो।काठमाडौं', ':', 'सरकारले', 'आकस्मिक', 'बाहेकका', 'शल्यक्रिया', 'नगर्न', 'उपत्यकाका', 'सरकारी', 'अस्पताललाई', 'निर्देशन', 'दिएको', 'छ।काठमाडौं', ':', 'सरकारले', 'काठमाडौं', 'उपत्यकामा', 'रहेका', 'सरकारी', 'अस्पतालाई', 'कोभिड-१९', 'का', 'बिरामीको', 'उपचार', 'केन्द्रमा', 'परिणत', 'गर्ने', 'निर्णय', 'छ।', 'सोमबार', 'स्वास्थ्य', 'मन्त्री', 'भानुभक्त', 'ढकालको', 'उपस्थितिमा', 'बसेको', 'इन्सिडेन्ट', 'कमाण्ड', 'सिस्टमको', 'बैठकले', 'राजधानी', 'उपत्यकामा', 'सरकारी', 'अस्पताललाई', 'कोभिड', 'अस्पतालका', 'रुपमा', 'रुपान्तरण', 'गर्ने', 'निर्णय', 'लिएको', 'हो।', 'काठमाडौं', ':', 'स्वास्थ्य', 'तथा', 'जनसंख्या', 'मन्त्रालयले', 'दहचोकमा', 'रहेको', 'प्रस्तावि', 'मनमोहन', 'मेमोरियल', 'मेडिकल', 'कलेज', 'कीर्तिपुरमा', 'रहेको', 'आयुर्वेद', 'अनुसन्धान', 'तथा', 'तालिम', 'केन्द्र', 'शिक्षण', 'अस्पताललाई', 'लक्षण', 'सहितको', 'कोभिड', '(', '१९', 'संक्रमितको', 'उपचार', 'गर्ने', 'अस्पतालको', 'रुपमा', 'स्तरउन्नति', 'गर्ने', 'निर्णय', '।सर्लाही', ':', 'घुँगी', 'बेचेर', 'सर्लाही', 'धनकौल', 'गाउँपालिका–२', 'धापटोलकी', 'उर्मिलादेवी', 'सहनीले', 'परिवार', 'पाल्दै', 'आएकी', 'छन्।', 'सानोतिनो', 'खर्च', 'टार्न', 'श्रीमानकै', 'पर्नुपर्ने', 'उर्मिलालाई', 'अहिले', 'त्यति', 'सारो', 'चिन्ता', 'छैन।', 'उनी', 'आम्दानीले', 'घर', 'व्यवहार', 'चलाउन', 'भएकी', 'छन्।', 'सर्लाही', ':', 'घुँगी', 'बेचेर', 'सर्लाही', 'धनकौल', 'गाउँपालिका–२', 'धापटोलकी', 'उर्मिलादेवी', 'सहनीले', 'परिवार', 'पाल्दै', 'आएकी', 'छन्।', 'सानोतिनो', 'खर्च', 'टार्न', 'श्रीमानकै', 'पर्नुपर्ने', 'उर्मिलालाई', 'अहिले', 'त्यति', 'सारो', 'चिन्ता', 'छैन।', 'उनी', 'आम्दानीले', 'घर', 'व्यवहार', 'चलाउन', 'भएकी', 'छन्।', 'बुटवल', ':', 'बुटवलस्थित', 'लुम्बिनी', 'प्रादेशिक', 'अस्पतालमा', 'थप', 'एकजना', 'संक्रमितको', 'मृत्यु', 'छ।', 'सुर्खेत', ':', '२०७६', 'चैत्र', '१', 'गते', 'थाहाखबर', 'डटकममा', 'एउटा', 'समाचार', 'प्रकाशित', 'भयो', ',', '‘', 'कर्णालीमा', 'मन्त्रीलाई', 'राजीनामाको', 'दबाबदेखि', 'क्षेत्रीय', 'पार्टी', 'खोल्नेसम्म।', '’', 'समाचारले', 'कर्णालीमा', 'नेकपाभित्रको', 'सत्ता', 'संघर्षलाई', 'उजागर', 'थियो।', 'वास्तविकता', '?', 'भौतिक', 'मन्त्रालयको', 'फन्डा', 'मुख्यमन्त्रीविरुद्ध', 'चौथो', 'धमाका', 'सरकारलाई', 'असहयोगको', 'आरोपसरकारको', 'कार्यशैलीकाठमाडौं', ':', 'सरकारले', 'तीव्र', 'गतिमा', 'फैलिएको', 'कोरोना', 'रोक्न', 'मानिसहरुलाई', 'जहाँको', 'त्यहीँ', 'दशैँ', 'मनाउने', 'रोक्ने', 'रणनीति', 'बनाएको', 'छ।काठमाडाैं', ':', '\u200bनेपालमा', 'कोरोना', 'भाइरस', '(', 'कोभिड-१९', ')', 'संक्रमित', 'निको', 'हुने', 'दर', 'घट्दै', 'गएको', 'छ।', 'अघिसम्म', 'कोरोना', 'संक्रमित', 'निको', 'हुने', 'दर', '७४', 'प्रतिशत', 'रहेको', 'अवस्थामा', 'घट्दै', 'गएको', 'हो।काठमाडौं', ':', 'नेपालमा', 'कोरोना', 'भाइरसको', 'संक्रमणबाट', 'थप', '९', 'जनाको', 'मृत्यु', 'छ।', 'स्वास्थ्य', 'तथा', 'जनसंख्या', 'मन्त्रालयका', '२४', 'घण्टामा', 'कोरोना', 'संक्रमणबाट', 'देशभर', '९', 'जनाको', 'मृत्यु', 'हो।सुर्खेत', ':', '२०७६', 'चैत्र', '१', 'गते', 'थाहाखबर', 'डटकममा', 'एउटा', 'समाचार', 'प्रकाशित', 'भयो', ',', '‘', 'कर्णालीमा', 'मन्त्रीलाई', 'राजीनामाको', 'दबाबदेखि', 'क्षेत्रीय', 'पार्टी', 'खोल्नेसम्म।', '’', 'समाचारले', 'कर्णालीमा', 'नेकपाभित्रको', 'सत्ता', 'संघर्षलाई', 'उजागर', 'थियो।', 'वास्तविकता', '?', 'भौतिक', 'मन्त्रालयको', 'फन्डा', 'मुख्यमन्त्रीविरुद्ध', 'चौथो', 'धमाका', 'सरकारलाई', 'असहयोगको', 'आरोपसरकारको', 'कार्यशैलीकाठमाडौं', ':', 'सरकारले', 'तीव्र', 'गतिमा', 'फैलिएको', 'कोरोना', 'रोक्न', 'मानिसहरुलाई', 'जहाँको', 'त्यहीँ', 'दशैँ', 'मनाउने', 'रोक्ने', 'रणनीति', 'बनाएको', 'छ।काठमाडाैं', ':', '\u200bनेपालमा', 'कोरोना', 'भाइरस', '(', 'कोभिड-१९', ')', 'संक्र ...

# %%
# wordfreq = []
# for w in filtered_sentence:
#     wordfreq.append(filtered_sentence.count(w))
# print("Pairs\n" + str(list(zip(filtered_sentence, wordfreq))))

# mylist = list(set(wordfreq))
# mylist.sort() 
# term_freq = mylist[-20:]
# print(term_freq)

SYMBOLS = ',—।()? ‘’१२३६४५७९०९०८–:'
results = []
for element in filtered_sentence:
    temp = ""
    for ch in element:
        if ch not in SYMBOLS:
            temp += ch

    results.append(temp)
    
while("" in results) : 
    results.remove("") 
#     results.remove("‘") 
    
print(results)

with open("/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/5-sites-coupus-removed-stopwords.txt", "a+") as f:
    for text in results:  
        f.write("%s\n" % text)
    f.close()
# Out:
# ['काठमाडौं', 'बागमती', 'प्रदेशको', 'ठूलो', 'भर्\u200dयाङस्थित', 'यातायात', 'व्यवस्था', 'कार्यालयका', 'जना', 'कर्मचारीमा', 'कोरोना', 'पुष्टि', 'भएपछि', 'अनिश्चितकालका', 'छ', 'कार्यालयको', 'विज्ञप्तिमा', 'भनिएको', "'यस", 'कार्यालयमा', 'कार्यरत', 'कर्मचारीमा', 'कोरोना', 'पोजेटिभ', 'भएपछि', 'गते', 'मंगलबारदेखि', 'सूचना', 'जारी', 'नभए', 'सम्मको', 'गरिएको', "छ'एजेन्सी", 'बंगलादेशले', 'बलात्कारीलाई', 'मृत्युदण्ड', 'दिने', 'विधेयक', 'पारित', 'छ', 'बलात्कारीलाई', 'मृत्युदण्ड', 'दिनुपर्ने', 'आन्दोलन', 'चर्किएसँगै', 'सरकारले', 'मृत्युदण्ड', 'दिन', 'सकिने', 'कानुन', 'संशोधन', 'होकाठमाडौं', 'सरकारले', 'आकस्मिक', 'बाहेकका', 'शल्यक्रिया', 'नगर्न', 'उपत्यकाका', 'सरकारी', 'अस्पताललाई', 'निर्देशन', 'दिएको', 'छकाठमाडौं', 'सरकारले', 'काठमाडौं', 'उपत्यकामा', 'रहेका', 'सरकारी', 'अस्पतालाई', 'कोभिड-', 'का', 'बिरामीको', 'उपचार', 'केन्द्रमा', 'परिणत', 'गर्ने', 'निर्णय', 'छ', 'सोमबार', 'स्वास्थ्य', 'मन्त्री', 'भानुभक्त', 'ढकालको', 'उपस्थितिमा', 'बसेको', 'इन्सिडेन्ट', 'कमाण्ड', 'सिस्टमको', 'बैठकले', 'राजधानी', 'उपत्यकामा', 'सरकारी', 'अस्पताललाई', 'कोभिड', 'अस्पतालका', 'रुपमा', 'रुपान्तरण', 'गर्ने', 'निर्णय', 'लिएको', 'हो', 'काठमाडौं', 'स्वास्थ्य', 'तथा', 'जनसंख्या', 'मन्त्रालयले', 'दहचोकमा', 'रहेको', 'प्रस्तावि', 'मनमोहन', 'मेमोरियल', 'मेडिकल', 'कलेज', 'कीर्तिपुरमा', 'रहेको', 'आयुर्वेद', 'अनुसन्धान', 'तथा', 'तालिम', 'केन्द्र', 'शिक्षण', 'अस्पताललाई', 'लक्षण', 'सहितको', 'कोभिड', 'संक्रमितको', 'उपचार', 'गर्ने', 'अस्पतालको', 'रुपमा', 'स्तरउन्नति', 'गर्ने', 'निर्णय', 'सर्लाही', 'घुँगी', 'बेचेर', 'सर्लाही', 'धनकौल', 'गाउँपालिका', 'धापटोलकी', 'उर्मिलादेवी', 'सहनीले', 'परिवार', 'पाल्दै', 'आएकी', 'छन्', 'सानोतिनो', 'खर्च', 'टार्न', 'श्रीमानकै', 'पर्नुपर्ने', 'उर्मिलालाई', 'अहिले', 'त्यति', 'सारो', 'चिन्ता', 'छैन', 'उनी', 'आम्दानीले', 'घर', 'व्यवहार', 'चलाउन', 'भएकी', 'छन्', 'सर्लाही', 'घुँगी', 'बेचेर', 'सर्लाही', 'धनकौल', 'गाउँपालिका', 'धापटोलकी', 'उर्मिलादेवी', 'सहनीले', 'परिवार', 'पाल्दै', 'आएकी', 'छन्', 'सानोतिनो', 'खर्च', 'टार्न', 'श्रीमानकै', 'पर्नुपर्ने', 'उर्मिलालाई', 'अहिले', 'त्यति', 'सारो', 'चिन्ता', 'छैन', 'उनी', 'आम्दानीले', 'घर', 'व्यवहार', 'चलाउन', 'भएकी', 'छन्', 'बुटवल', 'बुटवलस्थित', 'लुम्बिनी', 'प्रादेशिक', 'अस्पतालमा', 'थप', 'एकजना', 'संक्रमितको', 'मृत्यु', 'छ', 'सुर्खेत', 'चैत्र', 'गते', 'थाहाखबर', 'डटकममा', 'एउटा', 'समाचार', 'प्रकाशित', 'भयो', 'कर्णालीमा', 'मन्त्रीलाई', 'राजीनामाको', 'दबाबदेखि', 'क्षेत्रीय', 'पार्टी', 'खोल्नेसम्म', 'समाचारले', 'कर्णालीमा', 'नेकपाभित्रको', 'सत्ता', 'संघर्षलाई', 'उजागर', 'थियो', 'वास्तविकता', 'भौतिक', 'मन्त्रालयको', 'फन्डा', 'मुख्यमन्त्रीविरुद्ध', 'चौथो', 'धमाका', 'सरकारलाई', 'असहयोगको', 'आरोपसरकारको', 'कार्यशैलीकाठमाडौं', 'सरकारले', 'तीव्र', 'गतिमा', 'फैलिएको', 'कोरोना', 'रोक्न', 'मानिसहरुलाई', 'जहाँको', 'त्यहीँ', 'दशैँ', 'मनाउने', 'रोक्ने', 'रणनीति', 'बनाएको', 'छकाठमाडाैं', '\u200bनेपालमा', 'कोरोना', 'भाइरस', 'कोभिड-', 'संक्रमित', 'निको', 'हुने', 'दर', 'घट्दै', 'गएको', 'छ', 'अघिसम्म', 'कोरोना', 'संक्रमित', 'निको', 'हुने', 'दर', 'प्रतिशत', 'रहेको', 'अवस्थामा', 'घट्दै', 'गएको', 'होकाठमाडौं', 'नेपालमा', 'कोरोना', 'भाइरसको', 'संक्रमणबाट', 'थप', 'जनाको', 'मृत्यु', 'छ', 'स्वास्थ्य', 'तथा', 'जनसंख्या', 'मन्त्रालयका', 'घण्टामा', 'कोरोना', 'संक्रमणबाट', 'देशभर', 'जनाको', 'मृत्यु', 'होसुर्खेत', 'चैत्र', 'गते', 'थाहाखबर', 'डटकममा', 'एउटा', 'समाचार', 'प्रकाशित', 'भयो', 'कर्णालीमा', 'मन्त्रीलाई', 'राजीनामाको', 'दबाबदेखि', 'क्षेत्रीय', 'पार्टी', 'खोल्नेसम्म', 'समाचारले', 'कर्णालीमा', 'नेकपाभित्रको', 'सत्ता', 'संघर्षलाई', 'उजागर', 'थियो', 'वास्तविकता', 'भौतिक', 'मन्त्रालयको', 'फन्डा', 'मुख्यमन्त्रीविरुद्ध', 'चौथो', 'धमाका', 'सरकारलाई', 'असहयोगको', 'आरोपसरकारको', 'कार्यशैलीकाठमाडौं', 'सरकारले', 'तीव्र', 'गतिमा', 'फैलिएको', 'कोरोना', 'रोक्न', 'मानिसहरुलाई', 'जहाँको', 'त्यहीँ', 'दशैँ', 'मनाउने', 'रोक्ने', 'रणनीति', 'बनाएको', 'छकाठमाडाैं', '\u200bनेपालमा', 'कोरोना', 'भाइरस', 'कोभिड-', 'संक्रमित', 'निको', 'हुने', 'दर', 'घट्दै', 'गएको', 'छ', 'अघिसम्म', 'कोरोना', 'संक्रमित', 'निको', 'हुने', 'दर', 'प्रतिशत', 'रहेको', 'अवस्थामा', 'घट्दै', 'गएको', 'होकाठमाडौं', 'नेपालमा', 'कोरोना', 'भाइरसको', 'संक्रमणबाट', 'थप', 'जनाको', 'मृत्यु', ' ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d0c74ce8a1fc> in <module>
#      27 with open("/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/5-sites-coupus-removed-stopwords.txt", "a+") as f:
#      28     for text in results:
# ---> 29         f.write(text)
#      30         f.close()
#
# ValueError: I/O operation on closed file.

# %%
# wordfreq = []
# for w in results:
#     wordfreq.append(results.count(w))
# pairs = str(list(zip(results, wordfreq)))
# # print("Pairs\n" + pairs)
# pairs[(1)]


from collections import Counter
list1=results
counts = Counter(list1)
print(counts)

twenty_words = dict(Counter(counts).most_common(20))
# Out:
# Counter({'गर्ने': 188, 'छ': 147, 'सरकारले': 143, 'मृत्युदण्ड': 141, 'सरकारी': 141, 'अस्पताललाई': 141, 'निर्णय': 141, 'काठमाडौं': 140, 'कोरोना': 106, 'स्वास्थ्य': 96, 'तथा': 96, 'रहेको': 96, 'सर्लाही': 96, 'छन्': 96, 'कर्मचारीमा': 94, 'भएपछि': 94, 'बलात्कारीलाई': 94, 'उपत्यकामा': 94, 'उपचार': 94, 'कोभिड': 94, 'रुपमा': 94, 'गते': 49, 'होकाठमाडौं': 49, 'कोभिड-': 49, 'जनसंख्या': 49, 'संक्रमितको': 49, 'पुष्टि': 48, 'गरिएको': 48, 'छकाठमाडौं': 48, 'घुँगी': 48, 'बेचेर': 48, 'धनकौल': 48, 'गाउँपालिका': 48, 'धापटोलकी': 48, 'उर्मिलादेवी': 48, 'सहनीले': 48, 'परिवार': 48, 'पाल्दै': 48, 'आएकी': 48, 'सानोतिनो': 48, 'खर्च': 48, 'टार्न': 48, 'श्रीमानकै': 48, 'पर्नुपर्ने': 48, 'उर्मिलालाई': 48, 'अहिले': 48, 'त्यति': 48, 'सारो': 48, 'चिन्ता': 48, 'छैन': 48, 'उनी': 48, 'आम्दानीले': 48, 'घर': 48, 'व्यवहार': 48, 'चलाउन': 48, 'भएकी': 48, 'बागमती': 47, 'प्रदेशको': 47, 'ठूलो': 47, 'भर्\u200dयाङस्थित': 47, 'यातायात': 47, 'व्यवस्था': 47, 'कार्यालयका': 47, 'जना': 47, 'अनिश्चितकालका': 47, 'कार्यालयको': 47, 'विज्ञप्तिमा': 47, 'भनिएको': 47, "'यस": 47, 'कार्यालयमा': 47, 'कार्यरत': 47, 'पोजेटिभ': 47, 'मंगलबारदेखि': 47, 'सूचना': 47, 'जारी': 47, 'नभए': 47, 'सम्मको': 47, "छ'एजेन्सी": 47, 'बंगलादेशले': 47, 'दिने': 47, 'विधेयक': 47, 'पारित': 47, 'दिनुपर्ने': 47, 'आन्दोलन': 47, 'चर्किएसँगै': 47, 'दिन': 47, 'सकिने': 47, 'कानुन': 47, 'संशोधन': 47, 'आकस्मिक': 47, 'बाहेकका': 47, 'शल्यक्रिया': 47, 'नगर्न': 47, 'उपत्यकाका': 47, 'निर्देशन': 47, 'दिएको': 47, 'रहेका': 47, 'अस्पतालाई': 47, 'का': 47, 'बिरामीको': 47, 'केन्द्रमा': 47, 'परिणत': 47, 'सोमबार': 47, 'मन्त्री': 47, 'भानुभक्त': 47, 'ढकालको': 47, 'उपस्थितिमा': 47, 'बसेको': 47, 'इन्सिडेन्ट': 47, 'कमाण्ड': 47, 'सिस्टमको': 47, 'बैठकले': 47, 'राजधानी': 47, 'अस्पतालका': 47, 'रुपान्तरण': 47, 'लिएको': 47, 'हो': 47, 'मन्त्रालयले': 47, 'दहचोकमा': 47, 'प्रस्तावि': 47, 'मनमोहन': 47, 'मेमोरियल': 47, 'मेडिकल': 47, 'कलेज': 47, 'कीर्तिपुरमा': 47, 'आयुर्वेद': 47, 'अनुसन्धान': 47, 'तालिम': 47, 'केन्द्र': 47, 'शिक्षण': 47, 'लक्षण': 47, 'सहितको': 47, 'अस्पतालको': 47, 'स्तरउन्नति': 47, 'मृत्यु': 5, 'संक्रमित': 5, 'थप': 4, 'कर्णालीमा': 4, 'निको': 4, 'हुने': 4, 'दर': 4, 'घट्दै': 4, 'गएको': 4, 'संक्रमणबाट': 4, 'जनाको': 4, 'घण्टामा': 4, 'नेपालमा': 3, 'देशभर': 3, 'चैत्र': 2, 'थाहाखबर': 2, 'डटकममा': 2, 'एउटा': 2, 'समाचार': 2, 'प्रकाशित': 2, 'भयो': 2, 'मन्त्रीलाई': 2, 'राजीनामाको': 2, 'दबाबदेखि': 2, 'क्षेत्रीय': 2, 'पार्टी': 2, 'खोल्नेसम्म': 2, 'समाचारले': 2, 'नेकपाभित्रको': 2, 'सत्ता': 2, 'संघर्षलाई': 2, 'उजागर': 2, 'थियो': 2, 'वास्तविकता': 2, 'भौतिक': 2, 'मन्त्रालयको': 2, 'फन्डा': 2, 'मुख्यमन्त्रीविरुद्ध': 2, 'चौथो': 2, 'धमाका': 2, 'सरकारलाई': 2, 'असहयोगको': 2, 'आरोपसरकारको': 2, 'कार्यशैलीकाठमाडौं': 2, 'तीव्र': 2, 'गतिमा': 2, 'फैलिएको': 2, 'रोक्न': 2, 'मानिसहरुलाई': 2, 'जहाँको': 2, 'त्यहीँ': 2, 'दशैँ': 2, 'मनाउने': 2, 'रोक्ने': 2, 'रणनीति': 2, 'बनाएको': 2, 'छकाठमाडाैं': 2, '\u200bनेपालमा': 2, 'भाइरस': 2, 'अघिसम्म': 2, 'प्रतिशत': 2, 'अवस्थामा': 2, 'भाइरसको': 2, 'मन्त्रालयका': 2, 'हजार': 2, 'बुटवल': 1, 'बुटवलस्थित': 1, 'लुम्बिनी': 1, 'प्रादेशिक': 1, 'अस्पतालमा': 1, 'एकजना': 1, 'सुर्खेत': 1, 'होसुर्खेत': 1, 'होकाठमाडाैं': 1, 'कुल': 1, 'थपिएका': 1, 'छन्काठमाडौं': 1, 'बितेको': 1, 'देशका': 1, 'विभिन्न': 1, 'प्रयोगशालामा': 1, 'पिसिआर': 1, 'परीक्षणमा': 1, 'जनामा': 1, 'संक्रिय': 1, 'संख्या': 1})

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties


font_path = '/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/Preeti/mangal.ttf'
font = FontProperties(fname=font_path)

plt.rcParams["figure.figsize"] = (20,5)
# D = twenty_words
# plt.bar(*zip(*D.items()))
# plt.show()
# print(twenty_words)

keys = twenty_words.keys()
print(keys)
# values =twenty_words.values()

# plt.bar(twenty_words.keys(), values)



# plt.bar(*zip(*twenty_words.items()))
# plt.show()
# plt.bar(range(len(twenty_words)), twenty_words.values(), align='center')
# plt.xticks(range(len(twenty_words)), list(keys), rotation=70)
# label.set_fontproperties(font)
# plt.xlabel("Word")
# plt.ylabel("Count")


fig,ax = plt.subplots()
plt.bar(twenty_words.keys(), twenty_words.values(), align='center')
for label in ax.get_xticklabels():
    label.set_fontproperties(font)
plt.title('Term Frequency Graph')
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=90, fontsize=14)
plt.savefig("plot.png")
plt.show()
# Out:
# dict_keys(['गर्ने', 'छ', 'सरकारले', 'मृत्युदण्ड', 'सरकारी', 'अस्पताललाई', 'निर्णय', 'काठमाडौं', 'कोरोना', 'स्वास्थ्य', 'तथा', 'रहेको', 'सर्लाही', 'छन्', 'कर्मचारीमा', 'भएपछि', 'बलात्कारीलाई', 'उपत्यकामा', 'उपचार', 'कोभिड'])
# /home/sunil/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sunil/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
