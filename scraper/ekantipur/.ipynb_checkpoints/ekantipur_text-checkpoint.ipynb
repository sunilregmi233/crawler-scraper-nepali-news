# %%
import requests
from bs4 import BeautifulSoup
from datetime import date, timedelta


def get_data(url):
    with open("ekantipur_text.txt", "a+") as f:
        getpage= requests.get(url)
        soup= BeautifulSoup(getpage.text, 'html.parser')
        soup= BeautifulSoup(getpage.text, 'html.parser')
        ingredients = [ingredient.get_text() for ingredient in soup.select('div.description p')]
        f.write(str(ingredients))
        f.close()
    
if __name__ == "__main__":
    urls = []
    with open('ekantipur_links.txt', "r") as f:
        urls = f.read().splitlines()
    for i in urls:
        get_data(i)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
from datetime import date, timedelta

# urls = []
# with open('ekantipur.txt', "r") as f:
#     urls = f.read().splitlines()


getpage= requests.get('https://ekantipur.com/sports/2020/04/01/158570980044011985.html')
soup= BeautifulSoup(getpage.text, 'html.parser')
ingredients = {ingredient.get_text() for ingredient in soup.select('div.description p')}
print(ingredients)
# Out:
# {'', 'धादिङ — कोरोना भाइरस (कोभिड- १९)को संक्रमण फैलिनबाट रोक्न सरकारले दुई साता लामो लकडाउन गरेको छ\xa0। मुलुकभर अहिले लकडाउन चलिरहेको छ\xa0। यस्तो बेलामा अत्यावश्यक रूपमा सवारी साधन चलाउनका लागि प्रशासनले सवारी पास जारी गरिरहेका छन्\xa0।', "लकडाउनमा अत्यावश्यक परेको बेला सवारी साधन चलाउन लिइएको पास दुरुपयोग भएको र त्यसका नाममा बेथिति बढेपछि जिल्ला प्रशासन कार्यालय धादिङले भने सवारी पास लिनेहरूसँग सम्बन्धित वडाअध्यक्षको सिफारिस र गृह मन्त्रालयको सहमति माग गरेको छ\xa0। पृथ्वी राजमार्गमा सवारी साधन सञ्\u200dचालनमा कडाइ गरेको जिल्ला प्रशासनले सवारी पास वितरण रोकेको छ\xa0। विभिन्न उद्योगहरूमा काम गर्ने बाहिरी जिल्लाका मजदुरहरूलाई पठाउनका लागि ठेकेदार र मजदुर सञ्\u200dचालकहरूसँग वडा कार्यालयको सिफारिससहित गृह मन्त्रालयको सहमति माग्न थालेको छ\xa0। 'लकडाउनलाई थप प्रभावकारी बनाउन गृह मन्त्रालयले सवारी पास एक सातालाई जारी नगर्ने र अत्यावश्यक परेकालाई गृहको सहमति लिनुपर्ने परिपत्र आएपछि मजदुरहरू घर पठाउन सवारी पास लिन आएका ठेकेदार तथा उद्योगीहरूले मंगलबारबाट सवारी पास पाएका छैनन्,’ प्रमुख जिल
# ...
