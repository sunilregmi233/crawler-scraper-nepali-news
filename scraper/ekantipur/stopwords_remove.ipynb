# %%
from nltk.tokenize import word_tokenize
import nltk
import re

stopwords01 = open('../stopwords01.txt', 'r')
line = stopwords01.read()
words1 = word_tokenize(str(line))


stopwords = open('ekantipur_text.txt', 'r')
line1 = stopwords.read()
words2 = word_tokenize(str(line1))



SYMBOLS = ',—।()? ‘’१२३६४५७९०९०८–:-  र'
results = []
for element in words2:
    temp = ""
    for ch in element:
        if ch not in SYMBOLS:
            temp += ch

    results.append(temp)
    
while("" in results) : 
    results.remove("")

# %%
filtered_sentence = [w for w in results if not w in words1]
  
print(filtered_sentence)



with open("/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/5-sites-coupus-removed-stopwords.txt", "a+") as f:
    for text in filtered_sentence:  
        f.write("%s\n" % text)
    f.close()
# Out:
# ['लन्\u200dडन', 'व्षको', 'विम्बल्डन', 'स्थगित', 'हुने', 'निश्चित', 'स्थितिमा', 'पुगेको', 'यसका', 'त्यससँग', 'सम्बन्धित', 'आयोजक', 'पक्षबीच', 'छलफल', 'चलिहेको', 'अबको', 'घन्टामा', 'यसबाे', 'नि्णय', 'आउने', 'विश्वास', 'गिएको', 'प्तियोगिताको', 'आयोजक', 'अल', 'इंग्ल्यान्ड', 'क्लबले', 'स्थगित', 'ग्नेबाे', 'अहिलेसम्म', 'नि्णय', 'नभएपछि', 'यसबाे', 'छलफल', 'भइहेको', 'दोस्ो', 'विश्व', 'युद्धपछि', 'अहिलेसम्म', 'व्ष', 'विम्बल्डन', 'स्थगित', 'कोोना', 'भाइसको', 'संक्मणको', 'काण', 'यसपल्ट', 'स्थगित', 'हुने', 'स्थिति', 'सि्जना', 'तय', 'का्यक्मअनुसा', 'प्तियोगिता', 'जुन', 'बाट', 'सुु', 'हुनु', 'प्ने', 'अ्को', 'ग्ान्ड', 'स्लाम', 'प्तियोगिता', 'फ्ेन्च', 'ओपन', 'यसअघि', 'चा', 'महिनाका', 'पछाडि', 'सा्ने', 'नि्णय', 'भइसकेको', 'आयोजक', 'क्लबले', 'प्तियोगिताको', 'भविष्यबाे', 'इंग्ल्यान्डको', 'लन', 'टेनिस', 'संघ', 'व्यवसायिक', 'टेनिसको', 'संघ', 'महिला', 'टेनिस', 'संघसँग', 'छलफल', 'गिहेको', 'सिड्\u200dनी', 'अस्ट्ेलियाका', 'टेस्ट', 'कप्तान', 'टिम', 'पेनले', 'स्टिभ', 'स्मिथले', 'फेि', 'नेतृत्व', 'सम्हाल्ने', 'भने', 'आफूले', 'त्यसको', 'सम्थन', 'ग्ने', 'बताएका', 'सन्', 'मा्चमा', 'स्मिथमाथि', 'बल', 'टेम्पिङ', 'काण्डपछि', 'प्तिबन्ध', 'लागेको', 'दक्षिण', 'अफ्िकामा', 'त्यस', 'घटना', 'लगतै', 'व्षीय', 'पेनले', 'टेस्ट', 'टिमको', 'नेतृत्व', 'ग्ने', 'अवस', 'पाएका', 'एजेस', 'सििजका', 'क्ममा', 'व्षीय', 'स्मिथ', 'खेलाडीका', 'ूपमा', 'टिममा', 'फ्केका', 'उनीमाथि', 'टिमको', 'नेतृत्व', 'ग्नबाट', 'लागेको', 'व्षको', 'प्तिबन्ध', 'समाप्त', 'पेन', 'मान्छन्', 'स्मिथ', 'टिमको', 'कप्तानीमा', 'माउने', 'खालका', 'खेलाडी', 'हुन्', 'उनले', 'भने', 'स्मिथ', 'फेि', 'टेस्ट', 'टिममा', 'कप्तानको', 'भूमिकामा', 'फ्कन', 'चाहन्छन्', 'भने', 'मेो', 'पूा', 'सम्थन', 'हने', 'नेतृत्व', 'सम्हालेयता', 'पेनले', 'टेस्टमा', 'जित', 'निकालेका', 'बा्सिलोना', 'लियोनल', 'मेसीले', 'बा्सिलोनाका', 'खेलाडीले', 'तलब', 'प्तिशत', 'काटे', 'लिने', 'बताएका', 'कोोना', 'भाइसको', 'संक्मणले', 'पूा', 'स्पेन', 'आक्ान्त', 'भइहेको', 'बेला', 'क्लबलाई', 'आ्थिक', 'ूपमा', 'सहयोग', 'ग्न', 'खेलाडीले', 'नि्णय', 'गेका', 'हुन्', 'इन्स्ट्ाग्ाम', 'एकाउन्टमा', 'लामो', 'सन्देश', 'छोड्दै', 'मेसीले', 'क्लबका', 'अध्यक्ष', 'जोसेप', 'मािया', 'नेतृत्वमा', 'हेको', 'बो्डको', 'आलोचना', 'गेका', 'उनका', 'अनुसा', 'बो्डले', 'खेलाडीको', 'भावना', 'बुझ्न', 'सकेन्', 'स्पेनका', 'क्लबका', 'खेलाडीले', 'पूा', 'तलब', 'बुझ्ने', 'छैनन्', 'कोोनाको', 'माहामाीका', 'काण', 'अधिकांश', 'स्पेनी', 'क्लबको', 'आ्थिक', 'स्थिति', 'कमजो', 'मेसीले', 'लेखेका', 'आएको', 'विषम', 'पिस्थितिमा', 'खेलाडीले', 'तलब', 'प्तिशत', 'काटे', 'लिने', 'ग्दा', 'क्लबका', 'अू', 'क्मचाीले', 'शतप्तिशत', 'तबल', 'पाउने', 'सन्देशलाई', 'खेलाडीले', 'एकाउन्टमा', 'सेय', 'गेका', 'क्लबले', 'औपचािक', 'ूपमा', 'खेलाडीले', 'तलब', 'काटे', 'लिन', 'मानेको', 'जनाएको', 'काठमाडौँ', 'इन्डोनेसियाको', 'ाजधानी', 'जका्तामा', 'हेका', 'फुटबल', 'ोहित', 'चन्दले', 'देशमा', 'लकडाउन', 'नेपाली', 'नागिकले', 'क्वाेन्टाइनमा', 'बस्नेगी', 'स्वदेश', 'फ्कन', 'पाउनुप्ने', 'बताएका', 'संघीय', 'सकाले', 'कोोना', 'भाइस', 'कोभिड', 'महामाीबाट', 'बच्न', 'सातादेखि', 'लकडाउन', 'गेको', 'त्यसअघि', 'इन्डोनेसियाको', 'शी्ष', 'डिभिजनको', 'फुटबल', 'लिग', 'वान', 'नेपाली', 'मिडफिल्ड', 'ोहित', 'चन्द', 'समावेश', 'क्लब', 'प्सिजा', 'जका्ताको', 'खेल', 'कोोना', 'भाइसकै', 'काण', 'स्थगित', 'भइसकेको', 'फेि', 'खेल', 'सुचाु', 'हुने', 'मिति', 'कुेका', 'उनी', 'नेपालमा', 'लकडाउन', 'भएपछि', 'उतै', 'ोकिएका', 'जका्ताबाट', 'ोहितले', 'सोमबा', 'भने', 'फेि', 'लिग', 'सुु', 'हुने', 'नि्णय', 'पाएपछि', 'स्वदेश', 'फ्किने', 'सोचेको', 'थिएँ', 'नि्णय', 'आउनुअघि', 'नेपालमा', 'लकडाउन', 'भयो', 'स्वदेश', 'फ्किनका', 'तयाी', 'अवस्थामा', 'उनले', 'थपे', 'हिजो', 'लकडाउन', 'खुल्छ', 'भन्ने', 'आशा', 'फेि', 'लम्बियो', 'लकडाउन', 'ग्नु', 'देशका', 'ाम्ो', 'नागिकलाई', 'स्वदेश', 'दिनुप्ने', 'नेपालमा', 'क्वाेन्टाइन', 'बनाइएको', 'स्वदेश', 'फ्किनेलाई', 'बस्न', 'दिए', 'संक्मित', 'भए/नभएको', 'पीक्षण', 'भइहाल्छ', 'किअको', 'व्ष', 'इन्डोनेसियन', 'लिगमै', 'व्यस्त', 'हेका', 'ोहितले', 'भने', 'नेपाली', 'नागिक', 'भएकोले', 'देशमा', 'बस्न', 'पाए', 'हुन्थ्यो', 'भन्ने', 'लागिहेको', 'अुको', 'देशले', 'नागिक', 'उद्धा', 'लगिहेका', 'आफू', 'भने', 'बाहिै', 'हुँदा', 'नमाइलो', 'लाग्छ', 'सकाले', 'चैतदेखि', 'अन्त्ाष्ट्िय', 'उडान', 'य ...

# %%
# wordfreq = []
# for w in results:
#     wordfreq.append(results.count(w))
# pairs = str(list(zip(results, wordfreq)))
# # print("Pairs\n" + pairs)
# pairs[(1)]


from collections import Counter
list1=filtered_sentence
counts = Counter(list1)
print(counts)

twenty_words = dict(Counter(counts).most_common(20))
# Out:
# Counter({'भने': 168, 'खेलाडी': 90, 'उनले': 90, 'क्िकेट': 88, 'कोभिड': 86, 'हुने': 81, 'कोोना': 75, 'महिला': 68, 'उनी': 64, 'सन्': 61, 'लिग': 61, 'अन्त्ाष्ट्िय': 60, 'नि्णय': 58, 'गेका': 54, 'काण': 51, 'व्ष': 50, 'फुटबल': 50, 'गेको': 49, 'हुन्': 47, 'खेल': 47, 'भयो': 46, 'हेको': 44, 'नेपाली': 42, 'ग्ने': 41, 'खेलाडीले': 41, 'भाइसको': 40, 'स्थगित': 39, 'अहिले': 35, 'गिएको': 34, 'बेला': 34, 'सुु': 32, 'लकडाउन': 32, 'सकाले': 32, 'लाग्छ': 32, 'प्शिक्षक': 32, 'दोस्ो': 30, 'सहयोग': 30, 'नेपाल': 30, 'विश्व': 28, 'ग्न': 28, 'स्वदेश': 28, 'ग्दै': 28, 'मनोज': 28, 'भातीय': 28, 'प्शिक्षण': 28, 'फन': 28, 'गल्फ': 28, 'बाट': 26, 'फेि': 26, 'भन्ने': 26, 'बढी': 26, 'लाख': 26, 'हजा': 26, 'प्भावित': 26, 'ाष्ट्िय': 26, 'क्लबले': 25, 'भइहेको': 25, 'प्तियोगिता': 25, 'अनुसा': 25, 'भएका': 25, 'नेतृत्व': 24, 'नेपालमा': 24, 'खेलकुद': 24, 'ग्छन्': 24, 'ओलम्पिक्स': 24, 'प्दान': 24, 'यु': 24, 'नियम': 24, 'बिहीबा': 24, 'जापान': 24, 'दक्षिण': 23, 'पूा': 23, 'टिममा': 22, 'क्लब': 22, 'संक्मित': 22, 'मृत्यु': 22, 'ड': 22, 'उत्कृष्ट': 22, 'आयोजक': 21, 'टिम': 21, 'ूपमा': 21, 'दिन': 21, 'भइसकेको': 20, 'बताएका': 20, 'व्षीय': 20, 'जनाको': 20, 'टोकियो': 20, 'जाी': 20, 'बहिा': 20, 'अब्बल': 20, 'क्िकेटमा': 20, 'मात्': 20, 'भनेको': 20, 'काठमाडौँ': 19, 'जुन': 18, 'तलब': 18, 'ोहित': 18, 'ाम्ो': 18, 'आयोजना': 18, 'ड्युटीमा': 18, 'भन्छिन्': 18, 'चलिहेको': 17, 'प्तियोगिताको': 17, 'स्थिति': 17, 'कप्तान': 17, 'मा्चमा': 17, 'टिमको': 17, 'फ्कन': 17, 'भएपछि': 17, 'युोपेली': 17, 'मात्ै': 17, 'गाह्ो': 17, 'जानकाी': 17, 'विम्बल्डन': 16, 'प्ने': 16, 'लागेको': 16, 'काटे': 16, 'आ्थिक': 16, 'खेलाडीको': 16, 'वान': 16, 'ोहितले': 16, 'सोमबा': 16, 'ग्नु': 16, 'उपाधि': 16, 'लाक्पा': 16, 'डेब्यु': 16, 'लेविस': 16, 'व्षाले': 16, 'त्ास': 16, 'गौचन': 16, 'गौचनको': 16, 'गौचनले': 16, 'फ्लाइट': 16, 'जापानमा': 16, 'छलफल': 15, 'पछाडि': 15, 'टेस्ट': 15, 'पेनले': 15, 'स्मिथ': 15, 'छैनन्': 15, 'क्लबको': 15, 'यसमा': 15, 'पुुष': 15, 'तथा': 15, 'भनिन्': 15, 'पुगेको': 14, 'अहिलेसम्म': 14, 'यसअघि': 14, 'बल': 14, 'कोोनाको': 14, 'बस्न': 14, 'आफू': 14, 'हुँदा': 14, 'देखिएको': 14, 'कोड': 14, 'संख्या': 14, 'आइतबा': 14, 'जना': 14, 'नियमित': 14, 'धेै': 14, 'का': 14, 'उनलाई': 14, 'साता': 14, 'पूै': 14, 'काम': 14, 'घमै': 14, 'निश्चित': 13, 'संक्मणको': 13, 'ओपन': 13, 'टेनिस': 13, 'अवस': 13, 'घेलु': 13, 'व्षको': 12, 'स्थितिमा': 12, 'इंग्ल्यान्ड': 12, 'हुनु': 12, 'अ्को': 12, 'मेसीले': 12, 'प्तिशत': 12, 'सन्देश': 12, 'क्लबका': 12, 'अध्यक्ष': 12, 'हेका': 12, 'मिडफिल्ड': 12, 'जका्ताको': 12, 'इन्डोनेसियन': 12, 'इन्डोनेसियामा': 12, 'पुन': 12, 'प्सिजाले': 12, 'संक्मण': 12, 'महामाीले': 12, 'संक्मणका': 12, 'सहले': 12, 'सहको': 12, 'गुुङ': 12, 'ुविना': 12, 'ोमा': 12, 'थापा': 12, 'त्यही': 12, 'लाक्पाले': 12, 'प्द्शन': 12, 'खेलमा': 12, 'विकास': 12, 'ुपैंया': 12, 'प्कोप': 12, 'लिभपुललाई': 12, 'अगाडि': 12, 'स्थानमा': 12, 'डकव्थ': 12, 'डे': 12, 'जनताले': 12, 'पालना': 12, 'ुट्सको': 12, 'चिन्ता': 12, 'व्षदेखि': 12, 'हुन्छन्': 12, 'टोकियोमा': 12, 'जापानले': 12, 'बच्चाहूलाई': 12, 'यू': 12, 'ठूलो': 12, 'खेलाडीलाई': 12, 'त्यसको': 11, 'भाइस': 11, 'स्वाधिक': 11, 'सबैभन्दा': 11, 'यसबाे': 10, 'नभएपछि': 10, 'संघ': 10, 'सम्थन': 10, 'प्तिबन्ध': 10, 'संक्मणले': 10, 'आएको': 10, 'देशमा': 10, 'समावेश': 10, 'लागिहेको': 10, 'सचेत': 10, 'उल्लेख': 10, 'बसिहेका': 10, 'अु': 10, 'महामाी': 10, 'एसियाली': 10, 'प्तिस्प्धा': 10, 'सम्पू्ण': 10, 'त्यस्तै': 10, 'प्तियोगितामा': 10, 'सहभागी': 10, 'सुनाइन्': 10, 'एसिया': 10, 'मौका': 10, 'यस्तै': 10, 'नहुने': 10, 'सामान्य': 10, 'महामाीका': 10, 'लागू': 10, 'महसुस': 10, 'बनाएको': 10, 'बुधबा': 10, 'उनीसँग': 10, 'खासै': 10, 'सबैले': 10, 'आमा': 10, 'प्तिमा': 10, 'फो्ब्सको': 10, 'विश्वास': 9, 'ग्ान्ड': 9, 'गिहेको': 9, 'त्यस': 9, 'पाएका': 9, 'फ्केका': 9, 'मान्छन्': 9, 'चाहन्छन्': 9, 'मेो': 9, 'जित': 9, 'च्याम्पियन': 9, 'समेत': 9, 'दिइएको': 9, 'टिमका': 9, 'का्यक्म': 9, 'लिगका': 9, 'अल': 8, 'तय': 8, 'सा्ने': 8, 'टेनिसको': 8, 'लिने': 8, 'एकाउन्टमा': 8, 'उनका': 8, 'अधिकांश': 8, 'ग्दा': 8, 'जनाएको': 8, 'इन्डोनेसियाको': 8, 'ाजधानी': 8, 'शी्ष': 8, 'फ्किने': 8, 'तयाी': 8, 'अवस्थामा': 8, 'नागिकलाई': 8, 'दिए': 8, 'नागिक': 8, 'लगिहेका': ...

# %%
# mylist = list(set(wordfreq))
# mylist.sort() 
# term_freq = mylist[-20:]
# print(term_freq)
keys = twenty_words.keys()
print(keys)
# Out:
# dict_keys(['भने', 'खेलाडी', 'उनले', 'क्िकेट', 'कोभिड', 'हुने', 'कोोना', 'महिला', 'उनी', 'सन्', 'लिग', 'अन्त्ाष्ट्िय', 'नि्णय', 'गेका', 'काण', 'व्ष', 'फुटबल', 'गेको', 'हुन्', 'खेल'])

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties


font_path = '/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/Preeti/mangal.ttf'
font = FontProperties(fname=font_path)

plt.rcParams["figure.figsize"] = (20,10)

keys = twenty_words.keys()
print(keys)



fig,ax = plt.subplots()
plt.bar(twenty_words.keys(), twenty_words.values(), align='center')
for label in ax.get_xticklabels():
    label.set_fontproperties(font)
plt.title('Term Frequency Graph')
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=90, fontsize=14)
plt.savefig("plot.png")
plt.show()
# Out:
# dict_keys(['भने', 'खेलाडी', 'उनले', 'क्िकेट', 'कोभिड', 'हुने', 'कोोना', 'महिला', 'उनी', 'सन्', 'लिग', 'अन्त्ाष्ट्िय', 'नि्णय', 'गेका', 'काण', 'व्ष', 'फुटबल', 'गेको', 'हुन्', 'खेल'])
# /home/sunil/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sunil/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
