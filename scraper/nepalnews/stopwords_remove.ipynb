# %%
from nltk.tokenize import word_tokenize
import nltk
import re

stopwords01 = open('../stopwords01.txt', 'r')
line = stopwords01.read()
words1 = word_tokenize(str(line))


stopwords = open('nepalnews_text.txt', 'r')
line1 = stopwords.read()
words2 = word_tokenize(str(line1))



SYMBOLS = ',—।()? ‘’१२३६४५७९०९०८–:-  र'
results = []
for element in words2:
    temp = ""
    for ch in element:
        if ch not in SYMBOLS:
            temp += ch

    results.append(temp)
    
while("" in results) : 
    results.remove("")

# %%
filtered_sentence = [w for w in results if not w in words1]
  
print(filtered_sentence)



with open("/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/5-sites-coupus-removed-stopwords.txt", "a+") as f:
    for text in filtered_sentence:  
        f.write("%s\n" % text)
    f.close()
# Out:
# ['नेसन्स', 'लिग', 'फुटबलमा', 'ज्मनीले', 'युक्ेनलाई', 'हाएको', 'शनिबा', 'ाति', 'ज्मनीले', 'युक्ेनलाई', 'हाएको', 'विश्वकप', 'फुटबलमा', 'फाइनल', 'पुगेको', 'ज्मनीले', 'नेसन्स', 'लिग', 'फुटबलमा', 'जित', 'द्ता', 'गेको', 'उसले', 'समूह', 'चणको', 'सुुवाती', 'खेलमा', 'बाबी', 'खेल्दै', 'अंक', 'बाँडेको', 'खेलमा', 'अग्ता', 'औं', 'मिनेटमा', 'मथायस', 'गिन्टको', 'गोलमा', 'ज्मनीले', 'लिएको', 'लियोन', 'गोेत््जकाले', 'औं', 'मिनेटमा', 'ज्मनीका', 'अग्ता', 'दोब्ब', 'बनाउने', 'काम', 'घेलु', 'टोली', 'युक्ेनका', 'ुस्लान', 'मालिनोवस्कीले', 'सान्त्वना', 'गोल', 'फ्काए', 'ज्मनीले', 'व्ष', 'अघि', 'सुु', 'नेसन्स', 'लिगमा', 'जित', 'निकाल्न', 'सकेको', 'संस्कणमा', 'ज्मनीले', 'खेलबाट', 'अंक', 'जोडेको', 'किब', 'हजा', 'द्शक', 'क्षमताको', 'गशालामा', 'प्तिशत', 'द्शकलाई', 'प्वेश', 'अनुमती', 'प्दान', 'गिएको', 'सिजन', 'चेल्सीबाट', 'खेल्न', 'नपाएका', 'डिफेन्ड', 'एन्टोनियो', 'ुडीगले', 'प्भावशाली', 'प््दशन', 'उनले', 'ज्मनीको', 'सुुवाती', 'गोलका', 'सहयोग', 'उपलब्ध', 'गाए', 'चेल्सी', 'स्टा', 'काइ', 'हभा्ट्ज', 'टिमो', 'वा्नले', 'बेन्चबाट', 'खेलको', 'सुुवात', 'खेलाडी', 'खेलको', 'अन्तिममा', 'मैदान', 'प्वेश', 'गेका', 'ोयल', 'च्यालेन्ज्स', 'बैंगलोले', 'युएईमा', 'जाी', 'औं', 'संस्कणको', 'इन्डियन', 'प्िमिय', 'लिग', 'आईपीएल', 'टीट्वान्टी', 'क्िकेटमा', 'चौंथो', 'जित', 'निकालेको', 'दुबईमा', 'शनिबा', 'ाति', 'साविक', 'उपविजेता', 'चेन्नई', 'सुप', 'किङ्सलाई', 'नले', 'हाउँदै', 'बैंगलोले', 'चौंथो', 'जित', 'निकालेको', 'दुबई', 'अन्ताष्ट्िय', 'क्िकेट', 'स्टेडियममा', 'बैंगलोले', 'दिएको', 'सय', 'नको', 'लक्ष्यसहित', 'जवाफी', 'ब्याटिङ', 'गेको', 'चेन्नईले', 'ओभमा', 'विकेट', 'गुमाए', 'सय', 'मात्', 'बनाउन', 'सक्यो', 'चेन्नईका', 'अम्बाती', 'ायाडुले', 'स्वाधिक', 'बनाए', 'यस्तै', 'नाायण', 'जागाडिसनले', 'जोड्दा', 'शेन', 'वाट्सनले', 'कप्तान', 'महेन्द्', 'सिंह', 'धोनीले', 'बनाए', 'बैंगलोका', 'क्िस', 'मोिसले', 'विकेट', 'लिए', 'वासिङ्गटन', 'सुन्दको', 'नाममा', 'विकेट', 'ह्यो', 'अघि', 'टस', 'जिते', 'ब्याटिङ', 'गेको', 'बैंगलोले', 'ओभमा', 'विकेट', 'गुमाए', 'सय', 'बनाएको', 'बैंगलोका', 'कप्तान', 'विाट', 'कोहलीले', 'अविजित', 'हदै', 'नको', 'अ्धशतकीय', 'इनिङ्स', 'खेले', 'शिवम', 'डुबेले', 'अविजित', 'जोडे', 'यस्तै', 'देवदुत', 'पडीक्कलले', 'जोड्दा', 'वासिङ्गटन', 'सुन्दले', 'बनाए', 'आोन', 'फिन्च', 'नमा', 'आउट', 'हुँदा', 'एबी', 'भिलिय्स', 'सुन्य', 'नमा', 'आउट', 'चेन्नईका', 'सा्दुल', 'ठाकुले', 'तथा', 'साम', 'कण', 'दिपक', 'चाहले', 'विकेट', 'लिए', 'जितसँगै', 'बैंगलो', 'तालिकाको', 'चौंथो', 'स्थानमा', 'उक्लिएको', 'बैंगलोले', 'खेलमा', 'अंक', 'जोडेको', 'छैटौं', 'स्थानको', 'चेन्नईको', 'हा', 'खेलमा', 'चेन्नईले', 'अंक', 'जोडेको', 'नेपाली', 'लेग', 'स्पिन', 'सन्दीप', 'लामिछाने', 'आबद्द', 'दिल्ली', 'क्यापिटल्स', 'इन्डियन', 'प्िमिय', 'लिग', 'आईपीएल', 'टीट्वान्टी', 'क्िकेटको', 'शी्ष', 'स्थानमा', 'उक्लिएको', 'युएईको', 'साजाहमा', 'शुक्बा', 'ाति', 'खेलमा', 'ाजस्थान', 'ोयल्सलाई', 'नले', 'पाजित', 'ग्दै', 'दिल्ली', 'शी्ष', 'स्थानमा', 'उक्लिएको', 'साजाह', 'क्िकेट', 'स्टेडियममा', 'दिल्लीले', 'दिएको', 'सय', 'नको', 'लक्ष्यसहित', 'जवाफी', 'ब्याटिङ', 'गेको', 'ाजस्थान', 'ओभ', 'बलमा', 'अलआउट', 'हुँदै', 'सय', 'नमा', 'समेटियो', 'ाजस्थानका', 'ाहुल', 'टेवाटियाले', 'स्वाधिक', 'बनाए', 'यस्तै', 'याशभी', 'जैशवालले', 'जोड्दा', 'कप्तान', 'स्टिभ', 'स्मिथले', 'बनाए', 'जोस', 'बट्ल', 'नमा', 'आउट', 'ाजस्थानलाई', 'सस्तैमा', 'समेट्न', 'दिल्लीका', 'कागिसो', 'ाबडाले', 'विकेट', 'लिए', 'यस्तै', 'विचन्द्', 'आश्विन', 'मा्कुस', 'स्टोनिसले', 'विकेट', 'लिए', 'अक्ष', 'पटेल', 'ह्सल', 'पटेल', 'एन्ीच', 'नो्ट्जेको', 'नाममा', 'विकेट', 'ह्यो', 'अघि', 'टस', 'हाे', 'ब्याटिङ', 'गेको', 'दिल्लीले', 'ओभमा', 'विकेट', 'गुमाए', 'सय', 'बनाएको', 'दिल्लीका', 'शिम्न', 'हिटमायले', 'स्वाधिक', 'बनाए', 'यस्तै', 'मा्कुस', 'स्टोनिसले', 'जोड्दा', 'कप्तान', 'श्ेयस', 'आयले', 'बनाए', 'ओपनद्वय', 'पृथ्वी', 'श', 'शिख', 'धवन', 'नमा', 'आउट', 'अक्ष', 'पटेल', 'बनाउदा', 'ह्सल', 'पटेलले', 'जोडे', 'ाजस्थानका', 'जोफ्ा', 'आ्चले', 'विकेट', 'लिए', 'यस्तै', 'ाहुल', 'टिवाटिया', 'एन्ड्यु', 'टेइ', 'का्तिक', 'त्यागीले', 'विकेट', 'लिए', 'दिल्लीले', 'सन्दीपलाई', 'भने', 'मौका', 'दिएको', 'थिएँन', 'सन्दीप', 'लगाता', 'छैटौं', 'खेलमा', 'प्लेइङ', 'सेट', 'बाहि', 'हेका', 'हुन्', 'जितसँगै', 'शी्ष', 'स्थानमा', 'उक्लिएको', 'दिल्लीले', ...

# %%
# wordfreq = []
# for w in results:
#     wordfreq.append(results.count(w))
# pairs = str(list(zip(results, wordfreq)))
# # print("Pairs\n" + pairs)
# pairs[(1)]


from collections import Counter
list1=filtered_sentence
counts = Counter(list1)
print(counts)

twenty_words = dict(Counter(counts).most_common(20))
# Out:
# Counter({'गोल': 222, 'खेलमा': 220, 'गेको': 197, 'औं': 159, 'विकेट': 141, 'ग्दै': 132, 'सय': 131, 'मिनेटमा': 129, 'तथा': 120, 'गेका': 118, 'स्थानमा': 118, 'खेल': 116, 'दोस्ो': 113, 'हेको': 102, 'क्लब': 102, 'लिग': 100, 'जित': 98, 'ग्न': 95, 'भने': 93, 'उनले': 90, 'अंक': 88, 'ग्ने': 87, 'लिए': 82, 'नको': 77, 'यस्तै': 75, 'पाजित': 68, 'ाति': 61, 'अग्ता': 61, 'अघि': 61, 'मेस्सीले': 61, 'गिएको': 60, 'बनाए': 57, 'कप्तान': 57, 'खेलको': 56, 'तेस्ो': 54, 'काण': 54, 'प्िमिय': 53, 'हुन्': 53, 'समेत': 52, 'ाष्ट्िय': 51, 'सिजन': 50, 'ओभमा': 50, 'हेका': 47, 'लिगको': 47, 'व्ष': 45, 'खेलाडी': 45, 'बलमा': 45, 'बा्सिलोनाले': 45, 'क्िकेट': 44, 'नमा': 44, 'हुने': 44, 'बनाएको': 43, 'अविजित': 43, 'इनिङ्स': 43, 'कोोना': 43, 'प्हा': 42, 'शी्ष': 41, 'गत': 41, 'च्याम्पियन्स': 41, 'ब्याटिङ': 40, 'जोडेको': 39, 'जोडे': 39, 'फुटबल': 39, 'उपाधि': 39, 'गुमाए': 38, 'अ्धशतकीय': 38, 'उनी': 38, 'निकालेको': 37, 'सेन्ट': 37, 'पीएसजी': 37, 'दिएको': 36, 'पेनाल्टी': 36, 'घेलु': 35, 'सुु': 35, '
15, 'विश्व': 15, 'पू्वाधा': 15, 'काम': 14, 'प्दान': 14, 'बनाउन': 14, 'छैटौं': 14, 'नेपाली': 14, 'शुक्बा': 14, 'हुँदै': 14, 'टोलीलाई': 14, 'ाखेको': 14, 'नाइट': 14, 'कोलकत्ताले': 14, 'आन्द्े': 14, 'खेलाडीले': 14, 'विजेता': 14, 'पन्जाबले': 14, 'बल': 14, 'सकाले': 14, 'पूा': 14, 'सा्वजनिक': 14, 'थप': 14, 'सक्ने': 14, 'बनेका': 14, 'का्ड': 14, 'दिए': 14, 'ज्मन': 14, 'बाय्न': 14, 'जितेको': 14, 'पाएको': 14, 'नेपालका': 14, 'यथावत': 14, 'जमैका': 14, 'खेलबाट': 13, 'प्वेश': 13, 'स्टा': 13, 'चेन्नईका': 13, 'हदै': 13, 'ाहुल': 13, 'ोनाल्डो': 13, 'ग्यो': 13, 'विकास': 13, 'उल्लेख': 13, 'चा': 13, 'व्षको': 13, 'नि्णायक': 13, 'खेलाडीलाई': 13, 'लिन': 13, 'फुटबलको': 13, 'चौथो': 13, 'खेल्नेछ': 13, 'ए': 13, 'खेलाडीमा': 13, 'का': 13, 'तय': 13, 'प्स्ताव': 13, 'बलिङ': 13, 'उनलाई': 13, 'जित्न': 13, 'ब्खास्त': 13, 'शनिबा': 12, 'लिएको': 12, 'द्शक': 12, 'खेल्न': 12, 'चौंथो': 12, 'नाममा': 12, 'हुँदा': 12, 'दिल्ली': 12, 'ाजस्थान': 12, 'पछ्याएको': 12, 'दिलाउन': 12, 'पो्चुगलले': 12, 'मंगलबा': 12, 'ाजस्थानले': 12, 'नसक्दा': 12, 'पेको': 12, 'व्षीय': 12, 'गिने': 12, 'मन्त्ी': 12, 'व्यवस्था': 12, 'जना': 12, 'प्तिस्प्धा': 12, 'की्तिमानी': 12,  ...

# %%
# mylist = list(set(wordfreq))
# mylist.sort() 
# term_freq = mylist[-20:]
# print(term_freq)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties


font_path = '/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/Preeti/mangal.ttf'
font = FontProperties(fname=font_path)

plt.rcParams["figure.figsize"] = (20,5)
# D = twenty_words
# plt.bar(*zip(*D.items()))
# plt.show()
# print(twenty_words)

keys = twenty_words.keys()
print(keys)
# values =twenty_words.values()

# plt.bar(twenty_words.keys(), values)



# plt.bar(*zip(*twenty_words.items()))
# plt.show()
# plt.bar(range(len(twenty_words)), twenty_words.values(), align='center')
# plt.xticks(range(len(twenty_words)), list(keys), rotation=70)
# label.set_fontproperties(font)
# plt.xlabel("Word")
# plt.ylabel("Count")


fig,ax = plt.subplots()
plt.bar(twenty_words.keys(), twenty_words.values(), align='center')
for label in ax.get_xticklabels():
    label.set_fontproperties(font)
plt.title('Term Frequency Graph')
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=90, fontsize=14)
plt.savefig("plot.png")
plt.show()
# Out:
# dict_keys(['गोल', 'खेलमा', 'गेको', 'औं', 'विकेट', 'ग्दै', 'सय', 'मिनेटमा', 'तथा', 'गेका', 'स्थानमा', 'खेल', 'दोस्ो', 'हेको', 'क्लब', 'लिग', 'जित', 'ग्न', 'भने', 'उनले'])
