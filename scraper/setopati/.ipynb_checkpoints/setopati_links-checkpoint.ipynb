# %%
import requests
from bs4 import BeautifulSoup
from datetime import date, timedelta
import re

# with open('nepalnews_links.txt', "w") as f:
for i in range(1, 50):
    with open('setipati_links.txt', "a+") as f:
        url = "https://www.setopati.com/sports?page=" + str(i)
        getpage= requests.get(url)
        soup= BeautifulSoup(getpage.text, 'html.parser')
        ingredients = [ingredient for ingredient in soup.select('div.items a')]
        
        for j in ingredients:
            con = j['href']
            print(con)
            f.writelines(con + "\n")
        f.close()
# Out:
# https://www.setopati.com/sports/football/219274
# https://www.setopati.com/sports/sports-activity/219272
# https://www.setopati.com/sports/football/219270
# https://www.setopati.com/sports/cricket/219268
# https://www.setopati.com/sports/cricket/219255
# https://www.setopati.com/sports/sports-activity/219251
# https://www.setopati.com/sports/football/219228
# https://www.setopati.com/sports/sports-activity/219190
# https://www.setopati.com/sports/football/219188
# https://www.setopati.com/sports/cricket/219183
# https://www.setopati.com/sports/cricket/219179
# https://www.setopati.com/sports/football/219138
# https://www.setopati.com/sports/sports-activity/219135
# https://www.setopati.com/sports/cricket/219134
# https://www.setopati.com/sports/sports-activity/219096
# https://www.setopati.com/sports/football/219064
# https://www.setopati.com/sports/football/219056
# https://www.setopati.com/sports/cricket/219054
# https://www.setopati.com/sports/football/219036
# https://www.setopati.com/sports/football/219001
# https://www.setopati.com/sports/sports-activity/218977
# https://www.setopati.com/sports/football/218975
# https://www.setopati.com/sports/football/218972
# https://www.setopati.com/sports/cricket/218970
# https://www.setopati.com/sports/sports-activity/218935
# https://www.setopati.com/sports/football/218918
# https://www.setopati.com/sports/cricket/218879
# https://www.setopati.com/sports/cricket/218864
# https://www.setopati.com/sports/cricket/218857
# https://www.setopati.com/sports/sports-activity/218834
# #
# https://www.facebook.com/setopati/
# https://twitter.com/setopati
# https://www.youtube.com/user/setopati
# https://www.instagram.com/setopati/?hl=en
# https://www.setopati.com
# https://www.setopati.com/feed
# http://icc.setopati.com/
# https://setopati.com/coverstory/03
# http://election.setopati.com/
# https://www.setopati.com/sports/South-Asian-Games
# https://www.setopati.com/our-team
# https://www.setopati.com/sports/cricket/218812
# https://www.setopati.com/sports/cricket/218807
# https://www.setopati.com/sports/cricket/218788
# https://www.setopati.com/sports/football/218792
# https://www.setopati.com/sports/cricket/218771
# https://www.setopati.com/sports/football/218729
# https://www.setopati.com/sports/football/218699
# https://www.setopati.com/sports/football/218697
# https://www.setopati.com/sports/football/218694
# https://www.setopati.com/sports/football/218691
# https://www.setopati.com/sports/cricket/218688
# https://www.setopati.com/sports/cricket/218676
# https://www.setopati.com/sports/football/218672
# https://www.setopati.com/sports/cricket/218659
# https://www.setopati.com/sports/sports-activity/218632
# https://www.setopati.com/sports/football/218605
# https://www.setopati.com/sports/football/218603
# https://www.setopati.com/sports/cricket/218600
# https://www.setopati.com/sports/cricket/218587
# https://www.setopati.com/sports/football/218584
# https://www.setopati.com/sports/football/218544
# https://www.setopati.com/sports/football/218542
# https://www.setopati.com/sports/cricket/218541
# https://www.setopati.com/sports/cricket/218480
# https://www.setopati.com/sports/football/218463
# https://www.setopati.com/sports/football/218461
# https://www.setopati.com/sports/football/218458
# https://www.setopati.com/sports/football/217614
# https://www.setopati.com/sports/football/217593
# https://www.setopati.com/sports/cricket/217579
# #
# https://www.facebook.com/setopati/
# https://twitter.com/setopati
# https://www.youtube.com/user/setopati
# https://www.instagram.com/setopati/?hl=en
# https://www.setopati.com
# https://www.setopati.com/feed
# http://icc.setopati.com/
# https://setopati.com/coverstory/03
# http://election.setopati.com/
# https://www.setopati.com/sports/South-Asian-Games
# https://www.setopati.com/our-team
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-14d306a91c95> in <module>
#       8     with open('setipati_links.txt', "a+") as f:
#       9         url = "https://www.setopati.com/sports?page=" + str(i)
# ---> 10         getpage= requests.get(url)
#      11         soup= BeautifulSoup(getpage.text, 'html.parser')
#      12         ingredients = [ingredient for ingredient in soup.select('div.items a')]
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     663
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#     667                 method,
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     994         # Force connect early to allow us to validate the connection.
#     995         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 996             conn.connect()
#     997
#     998         if not conn.is_verified:
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in connect(self)
#     312     def connect(self):
#     313         # Add certificate verification
# --> 314         conn = self._new_conn()
#     315         hostname = self.host
#     316
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in _new_conn(self)
#     157
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59     family = allowed_gai_family()
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#      63         sock = None
#
# /usr/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     916     # and socket type values to enum constants.
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#     920         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
# url = "https://www.setopati.com/sports?page=2" 
# getpage= requests.get(url)
# soup= BeautifulSoup(getpage.text, 'html.parser')
# ingredients = [ingredient for ingredient in soup.select('div.items a')]

# for j in ingredients:
#     con = j['href']
#     print(con)
# Out:
# [<a href="https://www.setopati.com/sports/cricket/218812" title="बाटो काट्दा कारले ठक्कर दिएपछि अफगानिस्तानका ब्याट्सम्यानको निधन">
# <figure>
# <img alt="" src="https://img.setoparty.com/uploads/posts/450X285/Najeeb.jpg1601964232.jpg"/>
# <span class="tags">क्रिकेट</span> </figure>
# <span class="main-title">बाटो काट्दा कारले ठक्कर दिएपछि अफगानिस्तानका ब्याट्सम्यानको निधन</span>
# </a>, <a href="https://www.setopati.com/sports/cricket/218807" title="सट्टेबाजले सम्पर्क गर्न खोजेपछि आइपिएलका खेलाडीमाथि छानबिन">
# <figure>
# <img alt="" src="https://img.setoparty.com/uploads/posts/450X285/ipl.jpg1601961503.jpg"/>
# <span class="tags">क्रिकेट</span> </figure>
# <span class="main-title">सट्टेबाजले सम्पर्क गर्न खोजेपछि आइपिएलका खेलाडीमाथि छानबिन</span>
# </a>, <a href="https://www.setopati.com/sports/cricket/218788" title="दिल्लीको उत्कृष्ट प्रदर्शन, बेंग्लोरलाई हराउँदै उक्लियो शीर्ष स्थानमा">
# <figure>
# <img alt="" src="https://img.setoparty.com/uploads/posts/450X285/dc win.jpg1601945734.jpg"/>
# <span class="tags">क्रिकेट</span> </figure>
# <span class="main-title">दिल्लीको उत्कृष्ट प्रदर्शन, बेंग्लोरलाई हराउँदै उक्लियो शीर्ष स्थानमा</span>
# </a>, <a href="https://www.setopati.com/sports/football/218792" title="काभानी म्यानचेस्टर युनाइटेडमा आबद्ध">
# <figure>
# <img alt="" src="https://img.setoparty.com/uploads/posts/450X285/cavani new.jpg1601947168.jpg"/>
# <span class="tags">फुटबल</span>
# </figure>
# <span class="main-title">काभानी म्यानचेस्टर युनाइटेडमा आबद्ध</span> </a>, <a href="https://www.setopati.com/sports/cricket/218771" title="दिल्लीका स्पिनर अमित मिश्राले आइपिएलका बाँकी खेल गुमाउने">
# <figure>
# <img alt="" src="https://img.setoparty.com/uploads/posts/450X285
# <span class="tags">क्रिकेट</span>
# </figure>
# <span class="main-title">क्यानका अध्यक्ष र सचिवलाई कोरोना संक्रमण</span> </a>, <a href="#" title="Setopati">
# <img alt="" src="https://www.setopati.com/themes/setopati/images/logo.svg?v=1.2">
# </img></a>, <a href="https://www.facebook.com/setopati/" target="_blank" title="Like us on Facebook"><span class="left-icon twitter fa fa-facebook"></span><span class="social-title">Like us on Facebook</span></a>, <a href="https://twitter.com/setopati" target="_blank" title="Follow us on Twiiter"><span class="left-icon twitter fa fa-twitter"></span><span class="social-title">Follow us on Twitter</span></a>, <a href="https://www.youtube.com/user/setopati" target="_blank" title="Subscribe YouTube Channel"><span class="left-icon youtube fa fa-youtube"></span><span class="social-title">Subscribe YouTube Channel</span></a>, <a href="https://www.instagram.com/setopati/?hl=en" target="_blank" title="Follow us on Instagram"><span class="left-icon instagram fa fa-instagram"></span><span class="social-title">Follow us on Instagram</span></a>, <a href="https://www.setopati.com" title="गृहपृष्ठ">गृहपृष्ठ</a>, <a href="https://www.setopati.com/feed" title="फिड">फिड</a>, <a href="http://icc.setopati.com/" target="_blank" title="ICC #CT2017">ICC #CT2017</a>, <a href="https://setopati.com/coverstory/03" target="_blank" title="सेभेन डेज इन टिबेट">सेभेन डेज इन टिबेट</a>, <a href="http://election.setopati.com/" target="_blank" title="Election 2017">Election 2017</a>, <a href="https://www.setopati.com/sports/South-Asian-Games" target="_blank">१३औं दक्षिण एसियाली खेलकुद</a>, <a href="https://www.setopati.com/our-team" title="सेतोपाटी टीम">हाम्रो टीम</a>]
# https://www.setopati.com/sports/cricket/218812
# https://www.setopati.com/sports/cricket/218807
# https://www.setopati.com/sports/cricket/218788
# https://www.setopati.com/sports/football/218792
# https://www.setopati.com/sports/cricket/218771
# https://www.setopati.com/sports/football/218729
# https://www.setopati.com/sports/football/218699
# https://www.setopati.com/sports/football/218697
# https://www.setopati.com/sports/football/218694
# https://www.setopati.com/sports/football/218691
# https://www.setopati.com/sports/cricket/218688
# https://www.setopati.com/sports/cricket/218676
# https://www.setopati.com/sports/football/218672
# https://www.setopati.com/sports/cricket/218659
# https://www.setopati.com/sports/sports-activity/218632
# https://www.setopati.com/sports/football/218605
# https://www.setopati.com/sports/football/218603
# https://www.setopati.com/sports/cricket/218600
# https://www.setopati.com/sports/cricket/218587
# https://www.setopati.com/sports/football/218584
# https://www.setopati.com/sports/football/218544
# https://www.setopati.com/sports/football/218542
# https://www.setopati.com/sports/cricket/218541
# https://www.setopati.com/sports/cricket/218480
# https://www.setopati.com/sports/football/218463
# https://www.setopati.com/sports/football/218461
# https://www.setopati.com/sports/football/218458
# https://www.setopati.com/sports/cricket/218456
# https://www.setopati.com/sports/football/218454
# https://www.setopati.com/sports/cricket/218428
# #
# https://www.facebook.com/setopati/
# https://twitter.com/setopati
# https://www.youtube.com/user/setopati
# https://www.instagram.com/setopati/?hl=en
# https://www.setopati.com
# https://www.setopati.com/feed
# http://icc.setopati.com/
# https://setopati.com/coverstory/03
# http://election.setopati.com/
# https://www.setopati.com/sports/South-Asian-Games
# https://www.setopati.com/our-team
