# %%
from nltk.tokenize import word_tokenize
import nltk
import re

stopwords01 = open('../stopwords01.txt', 'r')
line = stopwords01.read()
words1 = word_tokenize(str(line))


stopwords = open('souryaonline_text.txt', 'r')
line1 = stopwords.read()
words2 = word_tokenize(str(line1))



SYMBOLS = ',—।()? ‘’१२३६४५७९०९०८–:'
results = []
for element in words2:
    temp = ""
    for ch in element:
        if ch not in SYMBOLS:
            temp += ch

    results.append(temp)
    
while("" in results) : 
    results.remove("")

# %%
filtered_sentence = [w for w in results if not w in words1]
  
print(filtered_sentence)



with open("/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/5-sites-coupus-removed-stopwords.txt", "a+") as f:
    for text in filtered_sentence:  
        f.write("%s\n" % text)
    f.close()
# Out:
# ['दिल्ली', 'विराट', 'कोहलीका', 'शनिबार', 'खास', 'ब्याटिङको', 'स्टाइल', 'खास', 'मुहारमा', 'मुस्कान', 'खास', 'खुसी', 'जताउने', 'स्टाइल', 'खास', 'चेन्नईविरुद्ध', 'मिलेको', 'जीत', 'खास', 'रोयल', 'च्यालेन्जर्स', 'बैंग्लुरुका', 'कप्तान', 'विराट', 'कोहलीले', 'शनिबार', 'आईपीएलको', 'औँ', 'सिजनको', 'सबैभन्दा', 'ठूलो', 'व्यक्तिगत', 'स्कोर', 'नटआउट', 'रन', 'बनाए', 'कप्तानीमा', 'बैंग्लुरुले', 'चेन्नई', 'सुपर', 'किंग्सविरुद्ध', 'अहिलेसम्मको', 'सबैभन्दा', 'ठूलो', 'जीत', 'रनले', 'हासिल', 'गरे', 'रोयल', 'च्यालेन्जर्स', 'बैंग्लुरुका', 'फ्यानहरुले', 'कोहलीको', 'खास', 'प्रदर्शनको', 'कारण', 'खोजेका', 'फ्यान्सका', 'विराट', 'कोहलीको', 'स्पेसल', 'शो', 'जस', 'कसैलाई', 'मिल्छ', 'भने', 'उनी', 'अनुष्का', 'शर्मा', 'हुन्', 'विराटकी', 'पत्नी', 'अनुष्का', 'शनिबार', 'दुबईमा', 'खेलका', 'दौरान', 'मैदानमा', 'उपस्थित', 'थिइन्', 'बैंग्लुरु', 'विराट', 'कोहलीका', 'फ्यान', 'दाबी', 'गर्छन्', 'ब्रोडकास्टरले', 'क्यामेराले', 'अनुष्काको', 'अनुहार', 'देखाए', 'खेल', 'डिग्रीमा', 'बदलियो', 'म्याचको', 'दिशा', 'बदल्नमा', 'अनुष्काको', 'उपस्थिति', 'प्रेरणाको', 'कति', 'कारण', 'बन्यो', 'भन्ने', 'नाप्न', 'कठिन', 'सत्य', 'बैंग्लुरु', 'विराट', 'कोहलीको', 'पारीको', 'दौरान', 'शनिबार', 'प्रकारको', 'अन्दाज', 'बैंग्लुरुको', 'टोलीले', 'ओभरमा', 'रन', 'बनाएको', 'तब', 'विराट', 'कोहलीले', 'बलमा', 'रन', 'बनाएका', 'आगामी', 'बलमा', 'विराटले', 'रन', 'बनाए', 'कूल', 'बलमा', 'उनले', 'रन', 'जोडे', 'ओभरमा', 'बैंग्लुरुले', 'रन', 'जोडेर
 'पाएका', 'छैनन्', 'राजस्थान', 'रोयल्समा', 'दिग्गज', 'खेलाडी', 'कप्तान', 'स्टिभ', 'स्मिथ', 'जोस', 'बटलर', 'जोफ्रा', 'आर्चर', 'विदेशी', 'खेलाडी', 'नियमित', 'राजस्थानको', 'टोलीमा', 'खेल्दै', 'आएका', 'बेन', 'स्टोक्स', 'टोलीमा', 'सहभागी', 'हुनेछन्', 'राजस्थानमा', 'विदेशी', 'खेलाडीका', 'स्थान', 'अनुमान', 'सकिन्छ', 'डेबिड', 'मिलर', 'सिजन', 'राजस्थान', 'रोयल्सका', 'खेलसमेत', 'खेल्न', 'पाउने', 'छैनन्', 'कारण', 'उनी', 'टिम', 'सक्नेछन्', 'डेबिड', 'मिलर', 'पुरानो', 'टोली', 'किंग्स', 'इलेभेन', 'पन्जाबमा', 'सक्नेछन्', 'किनकि', 'पन्जाबको', 'मिडिल', 'अर्डरले', 'सिजन', 'निकै', 'खराब', 'प्रदर्शन', 'राजस्थान', 'रोयल्स', 'पूर्वकप्तान', 'दिल्ली', 'क्यापिटल्सका', 'वर्तमान', 'खेलाडी', 'अजिङ्क्य', 'रहाणेले', 'सिजन', 'खेल', 'खेल्न', 'पाएका', 'छैनन्', 'उहिलेसम्म', 'उनी', 'मैदानमा', 'ब्याट', 'नभई', 'पानीको', 'बोतल', 'बोकेर', 'दौडेको', 'पाइएको', 'यसै', 'कारण', ' ...

# %%
# wordfreq = []
# for w in results:
#     wordfreq.append(results.count(w))
# pairs = str(list(zip(results, wordfreq)))
# # print("Pairs\n" + pairs)
# pairs[(1)]


from collections import Counter
list1=filtered_sentence
counts = Counter(list1)
print(counts)

twenty_words = dict(Counter(counts).most_common(20))
# Out:
# Counter({'खेलमा': 301, 'रन': 287, 'बलमा': 267, 'खेल': 240, 'विकेट': 233, 'गर्दै': 208, 'रनमा': 202, 'औं': 198, 'ओभरमा': 189, 'उनले': 187, 'आउट': 178, 'भने': 173, 'सय': 161, 'तथा': 152, 'खेलाडी': 149, 'गरे': 148, 'गोल': 148, 'लिए': 129, 'गर्ने': 126, 'चौका': 126, 'रनको': 117, 'क्रिकेट': 116, 'राष्ट्रिय': 115, 'ओभरको': 115, 'रहेको': 114, 'लिग': 110, 'कारण': 108, 'हुने': 103, 'मिनेटमा': 98, 'खेलकुद': 95, 'क्याच': 92, 'भएका': 90, 'कप्तान': 89, 'प्रहार': 89, 'छक्का': 87, 'स्थानमा': 86, 'उत्कृष्ट': 85, 'नेपाली': 83, 'कोरोना': 83, 'क्लब': 83, 'जित': 82, 'प्रशिक्षण': 82, 'हजार': 80, 'गरिएको': 80, 'हुन्': 78, 'सहित': 78, 'पराजित': 77, 'खेलाडीको': 77, 'खर्चेर': 75, 'काठमाडौं': 74, 'नेपाल': 73, 'रहेका': 72, 'खेलको': 68, 'रुपमा': 68, 'उनी': 67, 'बताए': 67, 'अग्रता': 66, 'दिए': 66, 'प्रशिक्षक': 66, 'खेलाडीले': 64, 'प
': 26, 'दक्षिण': 26, 'दिएका': 26, 'खेले': 26, 'सो': 26, 'आइपिएल': 26, 'राति': 26, 'विकेटले': 26, 'प्रदेश': 26, 'शतक': 26, 'बोर्ड': 26, 'जमैकाले': 26, 'सहभागी': 25, 'समान': 25, 'बाँकी': 25, 'टोलीको': 25, 'हाफमा': 25, 'मैदान': 25, 'आयोजना': 25, 'आएको': 25, 'बलर': 25, 'राखेप': 25, 'मिलियन': 25, 'सम्झौता': 25, 'सुरुवात': 25, 'चन्दले': 25, 'छलफल': 25, 'सम्भावना': 24, 'लिगको': 24, 'रियल': 24, 'प्रतिस्पर्धा': 24, 'भन्दै': 24, 'विजेता': 24, 'बताएका': 24, 'लागेको': 24, 'बीमा': 24, 'रकम': 24, 'सक्ने': 23, 'फरवार्ड': 23, 'तीव्र': 23, 'च्याम्पियन्स': 23, 'लण्डन': 23, 'प्रर्दशन': 23, 'टेष्ट': 23, 'चेन्नई': 22, 'राजस्थान': 22, 'पाउने': 22, 'लिएको': 22, 'पेनाल्टी': 22, 'समयमा': 22, 'गतिका': 22, 'गतिविधि': 22, 'इन्डियन': 22, 'नेपालमा': 22, 'मिचेल': 22, 'बनाएका': 21, 'क्रममा': 21, 'गोलरक्षक': 21, 'मंगलबार': 21, 'टोलीलाई': 21, 'युरो': 21, 'तयार': 21, 'सम्पन्न': 21, 'बैठकले': 21, 'निर्माण': 21, 'एलबिडब्लू': 21, 'आईपीएल': 20, 'खेल्दै': 20, 'नाइट': 20, 'लगातार': 20, 'जितमा': 20, 'बलियो': 20, 'परिषद्': 20, 'संघका': 20, 'सार्वजनिक': 20, 'टम': 20, 'दिलाए': 19, 'मोहम्मद': 19, 'पुगेका': 19, 'विश्व': 19, 'प्रतिवेदन': 19, 'सिनियर': 19, 'खेलेको': 19, 'ओभर': 19, 'बराबरीमा': 19, 'गराउँदै': 19, 'करोड': 19, 'उपलब्ध': 19, 'क्यानको': 19, 'वार्षिक': 19, 'इंग्ल्यान्डले': 19, 'बराबरी': 18, 'सकेको': 18, 'क्लबले': 18, 'सुरुवाती': 18, 'नसक्दा': 18, 'राहुल': 1 ...

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties


font_path = '/home/sunil/Documents/Assignment_IS/crawler-scraper-nepali-news/Preeti/mangal.ttf'
font = FontProperties(fname=font_path)

plt.rcParams["figure.figsize"] = (20,5)

keys = twenty_words.keys()
print(keys)

fig,ax = plt.subplots()
plt.bar(twenty_words.keys(), twenty_words.values(), align='center')
for label in ax.get_xticklabels():
    label.set_fontproperties(font)
plt.title('Term Frequency Graph')
plt.xlabel("Word")
plt.ylabel("Count")
plt.xticks(rotation=90, fontsize=14)
plt.savefig("plot.png")
plt.show()
# Out:
# dict_keys(['खेलमा', 'रन', 'बलमा', 'खेल', 'विकेट', 'गर्दै', 'रनमा', 'औं', 'ओभरमा', 'उनले', 'आउट', 'भने', 'सय', 'तथा', 'खेलाडी', 'गरे', 'गोल', 'लिए', 'गर्ने', 'चौका'])
# /home/sunil/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/sunil/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
