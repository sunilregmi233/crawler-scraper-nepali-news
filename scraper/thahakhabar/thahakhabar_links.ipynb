# %%
import requests
from bs4 import BeautifulSoup
from datetime import date, timedelta
import re

# with open('nepalnews_links.txt', "w") as f:
for i in range(1,50):
    with open('thahakhabar_links.txt', "a+") as f:
        url = "http://thahakhabar.com/category/sports?page=" + str(i)
        getpage= requests.get(url)
        soup= BeautifulSoup(getpage.text, 'html.parser')
        ingredients = [ingredient for ingredient in soup.select('h4.entry-title a')]
        for j in ingredients:
            con = j['href']
            print(con)
            f.writelines("http://thahakhabar.com" + con + "\n")
            


#     start_date = date(2020, 4, 1)
#     end_date = date(2020, 10, 1)
#     delta = timedelta(days=1)
#     cus_date = []
#     while start_date <= end_date:
#         cus_date.append(start_date.strftime("%Y/%m/%d"))
#         start_date += delta
#     for i in cus_date:
#         get_link(url, i)
# Out:
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109914
# /news/109913
# /news/109898
# /news/109911
# /news/109910
# /news/109908
# /news/109898
# /news/109911
# /news/109910
# /news/109908
# /news/109907
# /news/109903
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# /news/109905
# /news/109918
# /news/109915
# /news/109917
# /news/109912
# /news/109914
# ...

# %%
# from datetime import date, timedelta

# start_date = date(2020, 4, 1)
# end_date = date(2020, 10, 1)
# delta = timedelta(days=1)
# cus_date = []
# while start_date <= end_date:
#     cus_date.append(start_date.strftime("%Y/%m/%d"))
#     start_date += delta

# print(cus_date)
